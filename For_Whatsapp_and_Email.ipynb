# %% [markdown]
# ## Face Recognition – Unlock Your Computer With Your Face!

# %% [markdown]
# ### Step 1 - Create Training Data

# %%
#..................Photo for Devesh......................
import cv2
import numpy as np

# Load HAAR face classifier
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Load functions
def face_extractor(img):
    # Function detects faces and returns the cropped face
    # If no face detected, it returns the input image
    
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    
    if faces is ():
        return None
    
    # Crop all faces found
    for (x,y,w,h) in faces:
        cropped_face = img[y:y+h, x:x+w]

    return cropped_face

# Initialize Webcam
cap = cv2.VideoCapture(0)
count = 0

# Collect 100 samples of your face from webcam input
while True:

    ret, frame = cap.read()
    if face_extractor(frame) is not None:
        count += 1
        face = cv2.resize(face_extractor(frame), (200, 200))
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)

        # Save file in specified directory with unique name
        file_name_path = './faces/devesh/' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, face)

        # Put count on images and display live count
        cv2.putText(face, str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper', face)
        
    else:
        print("Face not found")
        pass

    if cv2.waitKey(1) == 13 or count == 100: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()      
print("Collecting Samples Complete")
# Out:
# <>:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-5-807d293a7742>:16: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# ...

# %% [markdown]
# ### Step 2 - Train Model

# %%
cap.release()

# %% [markdown]
# # Model Trained for Devesh

# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# Get the training data we previously made
data_path = './faces/devesh/'
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]

# Create arrays for training data and labels
Training_Data, Labels = [], []

# Open training images in our datapath
# Create a numpy array for training data
for i, files in enumerate(onlyfiles):
    image_path = data_path + onlyfiles[i]
    images = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    Training_Data.append(np.asarray(images, dtype=np.uint8))
    Labels.append(i)

# Create a numpy array for both training data and labels
Labels = np.asarray(Labels, dtype=np.int32)

# Initialize facial recognizer
# model = cv2.face.createLBPHFaceRecognizer()
# NOTE: For OpenCV 3.0 use cv2.face.createLBPHFaceRecognizer()
# pip install opencv-contrib-python
# model = cv2.createLBPHFaceRecognizer()

devesh_model  = cv2.face_LBPHFaceRecognizer.create()
# Let's train our model 
devesh_model.train(np.asarray(Training_Data), np.asarray(Labels))
print("Model trained for Devesh sucessefully")
# Out:
# Model trained for Devesh sucessefully

# %% [markdown]
# ### Step 3 - Run Our Facial Recognition

# %%
import cv2
import numpy as np
import os
import pywhatkit
import smtplib

#............................................................................................................................


#whatsaap................
def whatsapp():
    #number=input("Enter the phone number:- ")
    pywhatkit.sendwhatmsg_instantly(phone_no="+918292687836", message="Heee i am  devesh....❗")
    print("Whatsapp Message sent Successfully!!")   
    
    
    
    
#sending email....................
def face_extractor1(img1):
    face_classifier2 = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    gray1 = cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
    faces1 = face_classifier2.detectMultiScale(gray1, 1.3, 5)
    
    if faces1 is ():
        return None
    
    for (x,y,w,h) in faces1:
        cropped_face1 = img1[y:y+h, x:x+w]
    return cropped_face1



#taking photo...................................
def tphoto():
    cap = cv2.VideoCapture(0)
    face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    ret1, frame1 = cap.read()
    if face_extractor1(frame1) is not None:
        face1 = cv2.resize(face_extractor1(frame1), (200, 200))
        face1 = cv2.cvtColor(face1, cv2.COLOR_BGR2GRAY)
        #cv2.putText(image, "Devesh", (50, 100), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        # Save file in specified directory with unique name
        cv2.imwrite("photo.jpg", face1)
        #cv2.destroyAllWindows()    
        print("photo clicked.........")
        
    else:
        print("Face not found")
        pass

    
    
#emailcode......................
def email():
    import variable
    import smtplib
    from email.message import EmailMessage
    import os
    import imghdr
    #send_to=input("Enter email id to send")
    tphoto()
    message=EmailMessage()
    message['From'] = "deveshkumaremail2@gmail.com"
    message['To'] = "amank4039@gmail.com"
    message['Subject'] = 'Face Recognition'
    message['Body']  = 'This is face of Devesh'


    #sub="tasting part 2"
    #body="using python sanding mail to aman by devesh using python script for task_6 for summer"
    #new="Subject:{}\n\n\n{}".format(sub,body)
    with open('photo.jpg', 'rb') as f:
            img_data = f.read()
            img_type=imghdr.what(f.name)
            img_name=f.name

    message.add_attachment(img_data, maintype='image', subtype=img_type, filename=img_name)
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp:
        smtp.login("deveshkumaremail2@gmail.com",variable.email_password)
        smtp.send_message(message)
        print("Email send Successfully!!!!!!!!!!!!!!!!!")




#..........................................................................................................................
# Out:
# <>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-7-07442b999637>:25: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces1 is ():

# %% [markdown]
# # ..........................................................................................................................

# %%
import cv2
import numpy as np
import os
import pywhatkit
import smtplib

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

def face_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img, []
    
    
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


    
    
    
    
    
    
# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, face = face_detector(frame)
    
    try:
        face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
        

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
        results = devesh_model.predict(face)
        
        # harry_model.predict(face)
        
        if results[1] < 500:
            confidence = int( 100 * (1 - (results[1])/400) )
            display_string = str(confidence) + '% Confident it is User'
            
        
            
        cv2.putText(image, display_string, (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2) 

        
        if confidence > 90:
            cv2.putText(image, "Hey Devesh", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
            cv2.imshow('Face Recognition', image )
            whatsapp()
            email()
            break
            
        else:
            cv2.putText(image, "I dont know, who r u", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
            cv2.imshow('Face Recognition', image )
       

    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "looking for face", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 13: #13 is the Enter Key
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-8-bf9a9c92a9a3>:14: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# Whatsapp Message sent Successfully!!
# photo clicked.........
# Email send Successfully!!!!!!!!!!!!!!!!!

# %%
cap.release()
